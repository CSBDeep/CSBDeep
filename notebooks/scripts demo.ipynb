# %% [markdown]
# # CARE Prediction

# %%
# %%bash
# care_predict

# %%
# %%bash
# care_predict \
# --input-dir     "./raw_data" \
# --input-pattern "tribolium/low/*.tif*" \
# --input-axes    "ZYX" \
# --norm-pmin     3 \
# --norm-pmax     99.8 \
# --model-basedir "." \
# --model-name    "my_model" \
# --output-dir    "./results" \
# --n-tiles       4

# %%
# %%bash
# tree raw_data results
